# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47              1.0
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03              2.0
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25              2.0
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44              1.0
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41              3.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %% [markdown]
# ### Put the dataset into Postgres
#
# 1. Create a conncection to Postgres

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root45@localhost:5432/ny_taxi')
engine.connect()

# %% [markdown]
# 2. Generate a schema (instruction) that specifies types and columns

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
from time import time

# %%
while True:
    t_start = time()
    
    df = next(df_iter)
    df = df.drop(columns=['Unnamed: 0'])
    
    # Changes dtype from TEXT to TIMESTAMP
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    
    # Adds rows to postgres db in 100k chunks
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
    
    t_end = time()
    duration = t_end - t_start
    
    print(f"inserted another chunk... took {duration:.3f} seconds")
# Out:
# inserted another chunk... took 12.545 seconds
# inserted another chunk... took 12.022 seconds
# inserted another chunk... took 12.270 seconds
# inserted another chunk... took 12.243 seconds
# inserted another chunk... took 12.153 seconds
# inserted another chunk... took 11.979 seconds
# inserted another chunk... took 12.042 seconds
# inserted another chunk... took 11.980 seconds
# inserted another chunk... took 12.706 seconds
# inserted another chunk... took 12.811 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-a57b539f873f> in <module>
#      10
#      11     # Adds rows to postgres db in 100k chunks
# ---> 12     df.to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
#      13
#      14     t_end = time()
#
# ...

# %%
a = 1.234567
print(f"{a:.3}")
# Out:
# 1.23
